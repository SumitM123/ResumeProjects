# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.10.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import LearningCurveDisplay, learning_curve
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Chronic Kidney Disease Detection/kidney_disease.csv')
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
# convert the target attribute to four categorical sections:
'''
0 (Healthy)	No CKD	sc < 1.2 (normal serum creatinine) & bu < 20
1 (Early CKD)	Mild	1.2 ≤ sc < 2.0 OR 20 ≤ bu < 40
2 (Moderate CKD)	Moderate	2.0 ≤ sc < 4.5 OR 40 ≤ bu < 70
3 (Severe CKD)	Severe	sc ≥ 4.5 OR bu ≥ 70
'''
def classifyTargetAttribute(sc, bu):
    if (sc < 1.2 and bu < 20):
        return 0
    elif (sc >= 1.2 and sc < 2.0) or (bu >= 20 and bu < 40):
        return 1
    elif (sc >= 2.0 and sc < 4.5) or (bu >= 40 and bu < 70):
        return 2
    else:
        return 3


data["classification"] = data.apply(lambda row: classifyTargetAttribute(row['sc'], row['bu']), axis=1)

# %%
# finding null values the dataframe
null_values = data.isnull().sum()
print(null_values)

print("Data types:")
print(data.dtypes)
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64
# Data types:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification      int64
# dtype: object

# %%
# From our findings round 38 percent of Red Blood Cell count (RBC) is missing, and 17 percent of Pus Cells (PC) is missing. Due to its large
# abundance of missing values, and its categorical nature which prevents us from replacing the missing values with a median, we're going to be
# removing features from our dataset

data = data.drop('rbc', axis=1)
data = data.drop('pc', axis=1)

# %%
data.columns = data.columns.str.strip()
# Now for the rest of the missing numerical values, we're going to be replacing it with the median, which is median imputation, for each category
# so it wouldn't be biased towards certain ends of the scale of the independent variable
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns[:-1]
data[numerical_columns] = data[numerical_columns].apply(lambda x: x.fillna(x.median()))

# replaced missing categorical data with mode imputation for the rest of the columns who's values aren't missing significantly
# This allows us to have the complete number of observations
categorical_columns = data.select_dtypes(include = ['object']).columns
data[categorical_columns] = data[categorical_columns].apply(lambda x: x.fillna(x.mode()))

# %%
print(data.shape[0])
# Out:
# 400

# %%
Y = data['classification']
X = data.drop('classification', axis=1)

# %%
# Normalize the features of the data

# Create a pipeline
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=42)

# This standardizes the numerical_columns
numerical_pipeline = Pipeline([
    ('standardize', StandardScaler())
])

# This does One-Hot Encoding of each categorical column
categorical_pipeline = Pipeline([
    ('encoding', OneHotEncoder(handle_unknown='ignore'))
])

preprocessing = ColumnTransformer([
    ('num', numerical_pipeline, numerical_columns),
    ('cat', categorical_pipeline, categorical_columns)
])

pipeline = Pipeline([
    ('preprocessing', preprocessing),
    ('model', LogisticRegression(penalty='l2',  solver='lbfgs', C=0.1, max_iter=1000))
])

# %%
numerical_columns[:-1]
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot'], dtype='object')

# %%
X_train
# Out:
#       id   age     bp     sg   al   su         pcc          ba    bgr     bu  \
# 124  124  65.0  100.0  1.015  0.0  0.0  notpresent  notpresent   90.0   98.0
# 294  294  75.0   60.0  1.020  0.0  0.0  notpresent  notpresent  110.0   50.0
# 255  255  34.0   80.0  1.025  0.0  0.0  notpresent  notpresent  121.0   27.0
# 78    78  70.0   80.0  1.020  0.0  0.0  notpresent  notpresent  158.0   85.0
# 101  101  71.0   90.0  1.015  2.0  0.0     present     present   88.0   80.0
# ..   ...   ...    ...    ...  ...  ...         ...         ...    ...    ...
# 71    71  46.0   60.0  1.010  1.0  0.0  notpresent  notpresent  163.0   92.0
# 106  106  50.0   90.0  1.020  0.0  0.0  notpresent  notpresent   89.0  118.0
# 270  270  23.0   80.0  1.025  0.0  0.0  notpresent  notpresent  111.0   34.0
# 348  348  38.0   80.0  1.020  0.0  0.0  notpresent  notpresent   99.0   19.0
# 102  102  17.0   60.0  1.010  0.0  0.0  notpresent  notpresent   92.0   32.0
#
#      ...  hemo  pcv     wc   rc  htn   dm cad appet   pe  ane
# 124  ...   9.1   28   5500  3.6  yes   no  no  good   no   no
# 294  ...  14.3   40   8300  5.8   no   no  no   NaN  NaN  NaN
# 255  ...  13.6   52   9200  6.3   no   no  no  good   no   no
# 78   ...  10.1   30    NaN  NaN  yes   no  no  good  yes   no
# 101  ...  11.3   33  10700  3.9   no   no  no  good   no   no
# ..   ...   ...  ...    ...  ...  ...  ...  ..   ...  ...  ...
# 71   ...   9.8   28  14600  3.2  yes  yes  no  good   no   no
# 106  ...   6.0   17   6500  NaN  yes  yes  no  good  yes  yes
# 270  ...  14.3   41   7200  5.0   no   no  no  good   no   no
# 348  ...  13.6   44   7300  6.4   no   no  no  good   no   no
# 102  ...  13.9   52   7000  NaN   no   no  no  good   no   no
#
# [340 rows x 23 columns]

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('standardize',
#                                                                    StandardScaler())]),
#                                                   Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot',
#        'hemo'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoding',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['pcc', 'ba', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad', 'appet', 'pe',
#        'ane'],
#       dtype='object'))])),
#                 ('model', LogisticRegression(C=0.1, max_iter=1000))])

# %%
pipeline.fit(X_train, y_train)

pipeline.predict(X_test)

'''
grid_search = GridSearchCV(pipeline, param_grid, cv=4, scoring='accuracy')
grid_search.fit(X_train, y_train)

print(f'The best hyperparameters: {grid_search.best_params_}')
print(f"Best Accuracy: {grid_search.best_score_}")
'''
# Out:
# '\ngrid_search = GridSearchCV(pipeline, param_grid, cv=4, scoring=\'accuracy\')\ngrid_search.fit(X_train, y_train)\n\nprint(f\'The best hyperparameters: {grid_search.best_params_}\')\nprint(f"Best Accuracy: {grid_search.best_score_}")\n'

# %%
pipeline.predict_proba(X_test)
# Out:
# array([[2.17215565e-01, 4.35562635e-01, 2.04410364e-01, 1.42811436e-01],
#        [8.40745843e-02, 7.06487687e-01, 1.73105903e-01, 3.63318252e-02],
#        [5.30391229e-02, 3.79563079e-01, 3.72494634e-01, 1.94903164e-01],
#        [5.70828449e-04, 5.21822020e-03, 2.52647549e-01, 7.41563402e-01],
#        [3.25324354e-03, 1.14202646e-01, 7.31480803e-01, 1.51063307e-01],
#        [6.90531660e-05, 3.27132251e-04, 9.48667098e-02, 9.04737105e-01],
#        [2.06403501e-01, 5.72140887e-01, 1.80048804e-01, 4.14068079e-02],
#        [3.59158767e-02, 5.39233584e-01, 3.16239942e-01, 1.08610598e-01],
#        [1.28130575e-01, 6.64795276e-01, 1.71786337e-01, 3.52878124e-02],
#        [4.54595231e-03, 7.32856244e-02, 4.91631005e-01, 4.30537418e-01],
#        [3.59571273e-03, 3.40948035e-02, 4.97607318e-01, 4.64702165e-01],
#        [1.89324434e-01, 5.53704233e-01, 2.16368788e-01, 4.06025452e-02],
#        [1.36135286e-04, 8.88743832e-03, 6.18229492e-01, 3.72746934e-01],
#        [1.78281751e-02, 6.99187076e-01, 2.24898090e-01, 5.80866580e-02],
#        [2.72981149e-04, 1.45548996e-03, 1.76861505e-01, 8.21410024e-01],
#        [7.21896201e-02, 6.73302886e-01, 1.81252391e-01, 7.32551030e-02],
#        [9.91932745e-02, 5.36502245e-01, 3.13426316e-01, 5.08781651e-02],
#        [1.19401826e-01, 6.88072524e-01, 1.77352132e-01, 1.51735181e-02],
#        [2.77477319e-02, 5.43934169e-01, 2.87015456e-01, 1.41302643e-01],
#        [7.97003077e-02, 6.58348697e-01, 2.41242520e-01, 2.07084750e-02],
#        [2.69911146e-02, 5.21299575e-01, 3.71780279e-01, 7.99290316e-02],
#        [1.43137864e-03, 3.44675932e-03, 2.06881528e-01, 7.88240334e-01],
#        [1.79981533e-01, 6.34403069e-01, 1.58274079e-01, 2.73413198e-02],
#        [2.50183836e-01, 5.87444041e-01, 1.12978341e-01, 4.93937823e-02],
#        [5.62802631e-02, 7.96961122e-01, 1.16713186e-01, 3.00454290e-02],
#        [1.22011475e-01, 6.02112969e-01, 2.35232659e-01, 4.06428971e-02],
#        [1.65360771e-01, 3.70945088e-01, 3.08447744e-01, 1.55246396e-01],
#        [1.33806431e-03, 1.98687074e-01, 6.78497600e-01, 1.21477261e-01],
#        [6.76191610e-02, 7.61028243e-01, 1.42849863e-01, 2.85027332e-02],
#        [2.43396109e-02, 2.55543464e-01, 3.61232894e-01, 3.58884031e-01],
#        [7.23138005e-02, 5.73350228e-01, 3.08891181e-01, 4.54447905e-02],
#        [6.84958910e-06, 1.60108321e-05, 2.22670080e-02, 9.77710132e-01],
#        [9.23128912e-02, 6.55523584e-01, 2.16828035e-01, 3.53354902e-02],
#        [1.17387899e-03, 1.19106264e-02, 2.87655112e-01, 6.99260383e-01],
#        [8.12473974e-02, 5.38969656e-01, 2.22753745e-01, 1.57029202e-01],
#        [8.92369272e-02, 7.27638282e-01, 1.27852914e-01, 5.52718767e-02],
#        [5.22925622e-02, 6.36879015e-01, 2.02557562e-01, 1.08270860e-01],
#        [9.63024233e-02, 4.60860612e-01, 3.80463849e-01, 6.23731156e-02],
#        [7.05074446e-03, 5.29947406e-01, 4.24696551e-01, 3.83052991e-02],
#        [7.58995160e-03, 3.89323515e-02, 4.42692420e-01, 5.10785277e-01],
#        [6.72714136e-02, 4.74314481e-01, 4.21885510e-01, 3.65285958e-02],
#        [8.06625175e-02, 5.27300263e-01, 2.22597770e-01, 1.69439450e-01],
#        [1.54862688e-03, 2.33023896e-02, 2.58856153e-01, 7.16292830e-01],
#        [4.18576426e-02, 3.31930753e-01, 4.73529429e-01, 1.52682175e-01],
#        [5.09799600e-02, 3.09677619e-01, 3.70199934e-01, 2.69142486e-01],
#        [1.15565273e-01, 5.90397030e-01, 2.62173475e-01, 3.18642225e-02],
#        [7.53239142e-04, 1.55118027e-03, 7.85519233e-03, 9.89840388e-01],
#        [7.50252949e-02, 3.95242400e-01, 4.40868355e-01, 8.88639499e-02],
#        [1.50814942e-03, 4.68162507e-03, 3.61178247e-01, 6.32631978e-01],
#        [3.40018496e-01, 5.44469843e-01, 6.18931366e-02, 5.36185246e-02],
#        [9.87399837e-02, 7.39535374e-01, 1.29418387e-01, 3.23062556e-02],
#        [6.58096336e-02, 5.12172860e-01, 3.77678182e-01, 4.43393245e-02],
#        [8.19305707e-02, 7.18036485e-01, 1.75646395e-01, 2.43865496e-02],
#        [7.03631299e-03, 9.08295655e-01, 7.94855673e-02, 5.18246425e-03],
#        [7.24341368e-02, 5.14715176e-01, 3.76840951e-01, 3.60097368e-02],
#        [1.33634851e-02, 3.52706263e-01, 5.42079034e-01, 9.18512182e-02],
#        [1.13345560e-02, 6.75480905e-01, 2.87131033e-01, 2.60535064e-02],
#        [3.79539805e-03, 8.68641993e-02, 7.20786275e-01, 1.88554128e-01],
#        [2.44985483e-03, 1.61116326e-02, 3.07072414e-01, 6.74366099e-01],
#        [1.04534949e-01, 7.14922637e-01, 1.31955772e-01, 4.85866428e-02]])

# %%
param_grid = {
    'model__C': [0.01, 0.1, 1, 10, 100],
}

grid_search = GridSearchCV(pipeline, param_grid, cv=4, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Best hyperparameters
print(f'The best hyperparameters: {grid_search.best_params_}')
print(f"Best Accuracy (CV): {grid_search.best_score_}")

# Evaluate on test set using best model
test_score = grid_search.score(X_test, y_test)
print(f"Test Accuracy: {test_score}")

print(f"From our findings, the training accuracy is 0.62 while the test accuracy is 0.61. Since the difference between the training and the test accuracy is")
print(f"marginal, it ensures that the model is not overfitting, and the futher regularization isn't needed. But due to the high training error, ")
print(f"it can be due the model underfitting the training data. Therefore, a more sophiticated model is ideal. ")
# Out:
# The best hyperparameters: {'model__C': 0.1}
# Best Accuracy (CV): 0.6294117647058823
# Test Accuracy: 0.6166666666666667
# From our findings, the training accuracy is 0.62 while the test accuracy is 0.61. Since the difference between the training and the test accuracy is
# marginal, it ensures that the model is not overfitting, and the futher regularization isn't needed. But due to the high training error,
# it can be due the model underfitting the training data. Therefore, a more sophiticated model is ideal.

# %%
print("Error Analysis")
labels = ["Healthy", "Early CKD", "Moderate CKD", "Severe CKD"]
y_pred = grid_search.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot()
# Out:
# Error Analysis

# %%
print("Now, I'm going to be going a seperate approach. Since it was evident that our model was severely underfitting the data, and that a ")
print("more powerful model is necessary, we're going to be implementing random forest approach to evaluate our data.")

rand_forest = RandomForestClassifier(n_estimators=30)
X_train = preprocessing.fit_transform(X_train)
X_test = preprocessing.transform(X_test)
rand_forest.fit(X_train, y_train)
rand_forest.predict(X_test)

param_grid_trees = {
    'n_estimators': [10, 20, 30, 40, 50, 60],
    'max_depth': [None, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10]
}

grid_search_trees = GridSearchCV(rand_forest, param_grid_trees, cv=4, scoring='accuracy')
grid_search_trees.fit(X_train, y_train)
grid_search_trees.predict(X_test)
grid_search_trees.predict_proba(X_test)

# Best hyperparameters
print(f'The best hyperparameters: {grid_search_trees.best_params_}')
print(f"Best Accuracy (CV): {grid_search_trees.best_score_}")
test_score1 = grid_search_trees.score(X_test, y_test)
print(f"Test Accuracy: {test_score1}")
# Out:
# Now, I'm going to be going a seperate approach. Since it was evident that our model was severely underfitting the data, and that a
# more powerful model is necessary, we're going to be implementing random forest approach to evaluate our data.
# The best hyperparameters: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 60}
# Best Accuracy (CV): 0.8
# Test Accuracy: 0.7666666666666667

# %%
print("When training with a random forest classifier, and running a grid search to find the best hyperparameters that maximizes the performance")
print("metric of accuracy, we've found that the max_depth of 20, min_samples_split: 2, and n_estimators of 40 seems to the optimal values. With a")
print("new accuracy of around 0.78, it significantly improved our model by around 0.15 when compared to the softmax regression model that was")
print("used previously. We'll try to further this improvement of accuracy via Extreme Gradient Boosting approach which sequencially trains models")
print("in which the model will learn from the mistakes of its precessors")
# Out:
# When training with a random forest classifier, and running a grid search to find the best hyperparameters that maximizes the performance
# metric of accuracy, we've found that the max_depth of 20, min_samples_split: 2, and n_estimators of 40 seems to the optimal values. With a
# new accuracy of around 0.78, it significantly improved our model by around 0.15 when compared to the softmax regression model that was
# used previously. We'll try to further this improvement of accuracy via Extreme Gradient Boosting approach which sequencially trains models
# in which the model will learn from the mistakes of its precessors

# %%
train_sizes, train_scores, test_scores = learning_curve(
    grid_search_trees.best_estimator_, X_train, y_train, cv=4, scoring='accuracy', n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Validation score')
plt.ylabel('Accuracy')
plt.xlabel('Training examples')
# Out:
# Text(0.5, 0, 'Training examples')

# %%
print("As you can see, the model is highly overfitting the data. More regularization is required.")
# Out:
# As you can see, the model is highly overfitting the data. More regularization is required.

# %%
param_grid_trees_2 = {
    'n_estimators': [10, 20, 30, 40, 50, 60],
    'max_depth': [None, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10],
    'max_features' : ["log2", 3, 4, 5]
}
print("We're going to run a randomSearch because it's better than GridSearch in finding hyperparameters that won't overfit the data.")
rand_search_trees = RandomizedSearchCV(rand_forest, param_grid_trees_2, scoring='accuracy', n_iter = 10, refit=True, cv=4)
rand_search_trees.fit(X_train, y_train)
rand_search_trees.predict(X_test)
print(rand_search_trees.get_params(deep=True))
test_score2 = rand_search_trees.score(X_test, y_test)
print(f"Test Accuracy: {test_score2}")
# rand_search_trees.predict_proba(X_train)
# Out:
# We're going to run a randomSearch because it's better than GridSearch in finding hyperparameters that won't overfit the data.
# {'cv': 4, 'error_score': nan, 'estimator__bootstrap': True, 'estimator__ccp_alpha': 0.0, 'estimator__class_weight': None, 'estimator__criterion': 'gini', 'estimator__max_depth': None, 'estimator__max_features': 'sqrt', 'estimator__max_leaf_nodes': None, 'estimator__max_samples': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__monotonic_cst': None, 'estimator__n_estimators': 30, 'estimator__n_jobs': None, 'estimator__oob_score': False, 'estimator__random_state': None, 'estimator__verbose': 0, 'estimator__warm_start': False, 'estimator': RandomForestClassifier(n_estimators=30), 'n_iter': 10, 'n_jobs': None, 'param_distributions': {'n_estimators': [10, 20, 30, 40, 50, 60], 'max_depth': [None, 5, 10, 15, 20], 'min_samples_split': [2, 5, 10], 'max_features': ['log2', 3, 4, 5]}, 'pre_dispatch': '2*n_jobs', 'random_state': None, 'refit': True, 'return_train_score': False, 'scoring': 'accuracy', 'verbose': 0}
# Test Accuracy: 0.75

# %%
train_sizes1, train_scores1, test_scores1 = learning_curve(
    rand_search_trees.best_estimator_, X_train, y_train, cv=4, scoring='accuracy', n_jobs=-1)

train_scores_mean1 = np.mean(train_scores1, axis=1)
test_scores_mean1 = np.mean(test_scores1, axis=1)

plt.plot(train_sizes1, train_scores_mean1, label='Training score')
plt.plot(train_sizes1, test_scores_mean1, label='Validation score')
plt.ylabel('Accuracy')
plt.xlabel('Training examples')
# Out:
# Text(0.5, 0, 'Training examples')

# %%
print("It looks like the model isn't overfitting the data as much as it did before through GridSearch. But it seems to have generalized worse with random search since the test accuracy was lower by 0.06.")
print("We'll proceed with a more random model that'll further generalize better by reducing variance, with a potential tradeoff of bias.")
# Out:
# It looks like the model isn't overfitting the data as much as it did before through GridSearch. But it seems to have generalized worse with random search since the test accuracy was lower by 0.06.
# We'll proceed with a more random model that'll further generalize better by reducing variance, with a potential tradeoff of bias.

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)


xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1.0,
    eval_metric='mlogloss',
    use_label_encoder=False
)

cv_strategy = StratifiedKFold(n_splits=5)

train_sizes2, train_scores2, test_scores2 = learning_curve(xgb_model,X_train,y_train_encoded,train_sizes=np.linspace(0.5, 1.0, 5),   scoring='accuracy',n_jobs=-1,cv=cv_strategy,error_score='raise'
)

train_scores_mean2 = np.mean(train_scores2, axis=1)
test_scores_mean2 = np.mean(test_scores2, axis=1)

plt.plot(train_sizes2, train_scores_mean2, label='Training score')
plt.plot(train_sizes2, test_scores_mean2, label='Validation score')
plt.ylabel('Accuracy')
plt.xlabel('Training examples')
plt.legend()
plt.title('Learning Curve: XGBoost')
plt.grid()
plt.show()

# %%
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Accuracy: 0.6167

# %%
if hasattr(X_train, 'toarray'):
    X_train_processed = X_train.toarray()
    X_test_processed = X_test.toarray()
else:
    X_train_processed = X_train
    X_test_processed = X_test

y_train_categorical = to_categorical(y_train, num_classes=4)
y_test_categorical = to_categorical(y_test, num_classes=4)

class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = {i: class_weights_array[i] for i in range(len(class_weights_array))}
print(f"Class weights: {class_weights}")

input_dim = X_train_processed.shape[1]

print(f"Input dimension: {input_dim}")
print(f"Training samples: {X_train_processed.shape[0]}")
print(f"Test samples: {X_test_processed.shape[0]}")
print(f"Class distribution in training: {np.bincount(y_train)}")

def build_improved_nn(input_dim, dropout_rate=0.3, l2_reg=0.01):
    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),

        layers.Dense(64, activation='relu',
                    kernel_regularizer=regularizers.l2(l2_reg),
                    name='hidden_layer_1'),
        layers.BatchNormalization(),
        layers.Dropout(dropout_rate),

        layers.Dense(32, activation='relu',
                    kernel_regularizer=regularizers.l2(l2_reg),
                    name='hidden_layer_2'),
        layers.BatchNormalization(),
        layers.Dropout(dropout_rate),

        layers.Dense(4, activation='softmax', name='output_layer')
    ])

    return model

nn_model = build_improved_nn(input_dim, dropout_rate=0.2, l2_reg=0.01)

nn_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

nn_model.summary()

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=30,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=15,
    min_lr=1e-7,
    verbose=1
)

print("\nTraining Improved Neural Network...")
history = nn_model.fit(
    X_train_processed, y_train_categorical,
    validation_split=0.2,
    epochs=300,
    batch_size=16,
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights,
    verbose=1
)

test_loss, test_accuracy = nn_model.evaluate(X_test_processed, y_test_categorical, verbose=0)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")

y_pred_proba = nn_model.predict(X_test_processed, verbose=0)
y_pred_nn = np.argmax(y_pred_proba, axis=1)

labels = ["Healthy", "Early CKD", "Moderate CKD", "Severe CKD"]
print("\nClassification Report:")
print(classification_report(y_test, y_pred_nn, target_names=labels))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy plot
axes[0].plot(history.history['accuracy'], label='Training Accuracy', alpha=0.8)
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy', alpha=0.8)
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Model Accuracy Over Epochs')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='Training Loss', alpha=0.8)
axes[1].plot(history.history['val_loss'], label='Validation Loss', alpha=0.8)
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].set_title('Model Loss Over Epochs')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print(f"Neural Network Test Accuracy: {test_accuracy:.4f}")
print("="*60)
# Out:
# Class weights: {0: np.float64(3.4), 1: np.float64(0.53125), 2: np.float64(0.8585858585858586), 3: np.float64(1.5178571428571428)}
# Input dimension: 215
# Training samples: 340
# Test samples: 60
# Class distribution in training: [ 25 160  99  56]
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 64)             │        13,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer_2 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,420 (64.14 KB)
#  Trainable params: 16,228 (63.39 KB)
#  Non-trainable params: 192 (768.00 B)
# Training Improved Neural Network...
# Epoch 1/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.1865 - loss: 3.5056 - val_accuracy: 0.2500 - val_loss: 2.7690 - learning_rate: 5.0000e-04
# Epoch 2/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2252 - loss: 3.2897 - val_accuracy: 0.2500 - val_loss: 2.6902 - learning_rate: 5.0000e-04
# Epoch 3/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2696 - loss: 2.8410 - val_accuracy: 0.2353 - val_loss: 2.6227 - learning_rate: 5.0000e-04
# Epoch 4/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3002 - loss: 2.8055 - val_accuracy: 0.2353 - val_loss: 2.5662 - learning_rate: 5.0000e-04
# Epoch 5/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3437 - loss: 2.4799 - val_accuracy: 0.3088 - val_loss: 2.5148 - learning_rate: 5.0000e-04
# Epoch 6/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3313 - loss: 2.5271 - val_accuracy: 0.3088 - val_loss: 2.4775 - learning_rate: 5.0000e-04
# Epoch 7/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4007 - loss: 2.2861 - val_accuracy: 0.3088 - val_loss: 2.4381 - learning_rate: 5.0000e-04
# Epoch 8/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3927 - loss: 2.2425 - val_accuracy: 0.3088 - val_loss: 2.3978 - learning_rate: 5.0000e-04
# Epoch 9/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3493 - loss: 2.2441 - val_accuracy: 0.3235 - val_loss: 2.3606 - learning_rate: 5.0000e-04
# Epoch 10/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3942 - loss: 2.1914 - val_accuracy: 0.3824 - val_loss: 2.3222 - learning_rate: 5.0000e-04
# Epoch 11/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4473 - loss: 2.0628 - val_accuracy: 0.3529 - val_loss: 2.2950 - learning_rate: 5.0000e-04
# Epoch 12/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4964 - loss: 2.0162 - val_accuracy: 0.3529 - val_loss: 2.2711 - learning_rate: 5.0000e-04
# Epoch 13/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5235 - loss: 1.8666 - val_accuracy: 0.3382 - val_loss: 2.2452 - learning_rate: 5.0000e-04
# Epoch 14/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5006 - loss: 1.9083 - val_accuracy: 0.3382 - val_loss: 2.2167 - learning_rate: 5.0000e-04
# Epoch 15/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5002 - loss: 1.8834 - val_accuracy: 0.3382 - val_loss: 2.2067 - learning_rate: 5.0000e-04
# Epoch 16/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5017 - loss: 1.8346 - val_accuracy: 0.3676 - val_loss: 2.1881 - learning_rate: 5.0000e-04
# Epoch 17/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5025 - loss: 1.7702 - val_accuracy: 0.3529 - val_loss: 2.1618 - learning_rate: 5.0000e-04
# Epoch 18/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5439 - loss: 1.7599 - val_accuracy: 0.4412 - val_loss: 2.1316 - learning_rate: 5.0000e-04
# Epoch 19/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6364 - loss: 1.5810 - val_accuracy: 0.4265 - val_loss: 2.1079 - learning_rate: 5.0000e-04
# Epoch 20/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5481 - loss: 1.6512 - val_accuracy: 0.4412 - val_loss: 2.0995 - learning_rate: 5.0000e-04
# Epoch 21/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6172 - loss: 1.6635 - val_accuracy: 0.4706 - val_loss: 2.0800 - learning_rate: 5.0000e-04
# Epoch 22/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6759 - loss: 1.5254 - val_accuracy: 0.4265 - val_loss: 2.0662 - learning_rate: 5.0000e-04
# Epoch 23/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6779 - loss: 1.5949 - val_accuracy: 0.4265 - val_loss: 2.0587 - learning_rate: 5.0000e-04
# Epoch 24/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6917 - loss: 1.4664 - val_accuracy: 0.4559 - val_loss: 2.0360 - learning_rate: 5.0000e-04
# Epoch 25/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6491 - loss: 1.6287 - val_accuracy: 0.4559 - val_loss: 2.0374 - learning_rate: 5.0000e-04
# Epoch 26/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7258 - loss: 1.4156 - val_accuracy: 0.4559 - val_loss: 2.0389 - learning_rate: 5.0000e-04
# Epoch 27/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6543 - loss: 1.5324 - val_accuracy: 0.4706 - val_loss: 2.0212 - learning_rate: 5.0000e-04
# Epoch 28/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7227 - loss: 1.3499 - val_accuracy: 0.4853 - val_loss: 2.0124 - learning_rate: 5.0000e-04
# Epoch 29/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7089 - loss: 1.4138 - val_accuracy: 0.5000 - val_loss: 2.0055 - learning_rate: 5.0000e-04
# Epoch 30/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7186 - loss: 1.4355 - val_accuracy: 0.4412 - val_loss: 1.9948 - learning_rate: 5.0000e-04
# Epoch 31/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7739 - loss: 1.2908 - val_accuracy: 0.5000 - val_loss: 1.9836 - learning_rate: 5.0000e-04
# Epoch 32/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7478 - loss: 1.3102 - val_accuracy: 0.5000 - val_loss: 1.9809 - learning_rate: 5.0000e-04
# Epoch 33/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7607 - loss: 1.2386 - val_accuracy: 0.5000 - val_loss: 1.9743 - learning_rate: 5.0000e-04
# Epoch 34/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7361 - loss: 1.3372 - val_accuracy: 0.4853 - val_loss: 1.9911 - learning_rate: 5.0000e-04
# Epoch 35/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7170 - loss: 1.3078 - val_accuracy: 0.4706 - val_loss: 1.9954 - learning_rate: 5.0000e-04
# Epoch 36/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7298 - loss: 1.2193 - val_accuracy: 0.4853 - val_loss: 1.9896 - learning_rate: 5.0000e-04
# Epoch 37/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7216 - loss: 1.2572 - val_accuracy: 0.5147 - val_loss: 1.9474 - learning_rate: 5.0000e-04
# Epoch 38/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7259 - loss: 1.2051 - val_accuracy: 0.4706 - val_loss: 1.9526 - learning_rate: 5.0000e-04
# Epoch 39/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7745 - loss: 1.2369 - val_accuracy: 0.4853 - val_loss: 1.9764 - learning_rate: 5.0000e-04
# Epoch 40/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7989 - loss: 1.1402 - val_accuracy: 0.4706 - val_loss: 1.9628 - learning_rate: 5.0000e-04
# Epoch 41/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7883 - loss: 1.1182 - val_accuracy: 0.4706 - val_loss: 1.9601 - learning_rate: 5.0000e-04
# Epoch 42/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7490 - loss: 1.1603 - val_accuracy: 0.4853 - val_loss: 1.9891 - learning_rate: 5.0000e-04
# Epoch 43/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8201 - loss: 1.1501 - val_accuracy: 0.5000 - val_loss: 1.9828 - learning_rate: 5.0000e-04
# Epoch 44/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8053 - loss: 1.0749 - val_accuracy: 0.5441 - val_loss: 1.9807 - learning_rate: 5.0000e-04
# Epoch 45/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8334 - loss: 1.0362 - val_accuracy: 0.5735 - val_loss: 1.9887 - learning_rate: 5.0000e-04
# Epoch 46/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8609 - loss: 1.0326 - val_accuracy: 0.5441 - val_loss: 1.9911 - learning_rate: 5.0000e-04
# Epoch 47/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7480 - loss: 1.1671 - val_accuracy: 0.5441 - val_loss: 2.0006 - learning_rate: 5.0000e-04
# Epoch 48/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8775 - loss: 0.9757 - val_accuracy: 0.5147 - val_loss: 2.0105 - learning_rate: 5.0000e-04
# Epoch 49/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8013 - loss: 1.1483 - val_accuracy: 0.4853 - val_loss: 2.0278 - learning_rate: 5.0000e-04
# Epoch 50/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8267 - loss: 1.0132 - val_accuracy: 0.4853 - val_loss: 2.0302 - learning_rate: 5.0000e-04
# Epoch 51/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8513 - loss: 1.0366 - val_accuracy: 0.5294 - val_loss: 2.0424 - learning_rate: 5.0000e-04
# Epoch 52/300
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8750 - loss: 0.8224
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8105 - loss: 1.0490 - val_accuracy: 0.5294 - val_loss: 2.0138 - learning_rate: 5.0000e-04
# Epoch 53/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8214 - loss: 0.9513 - val_accuracy: 0.5000 - val_loss: 2.0266 - learning_rate: 2.5000e-04
# Epoch 54/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8586 - loss: 0.9847 - val_accuracy: 0.5000 - val_loss: 2.0336 - learning_rate: 2.5000e-04
# Epoch 55/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9037 - loss: 0.8880 - val_accuracy: 0.4853 - val_loss: 2.0235 - learning_rate: 2.5000e-04
# Epoch 56/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7960 - loss: 0.9889 - val_accuracy: 0.4853 - val_loss: 2.0045 - learning_rate: 2.5000e-04
# Epoch 57/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8666 - loss: 0.9619 - val_accuracy: 0.5294 - val_loss: 2.0240 - learning_rate: 2.5000e-04
# Epoch 58/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9002 - loss: 0.8467 - val_accuracy: 0.5147 - val_loss: 2.0327 - learning_rate: 2.5000e-04
# Epoch 59/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8413 - loss: 0.9090 - val_accuracy: 0.5147 - val_loss: 2.0499 - learning_rate: 2.5000e-04
# Epoch 60/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8252 - loss: 0.9097 - val_accuracy: 0.5147 - val_loss: 2.0596 - learning_rate: 2.5000e-04
# Epoch 61/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8565 - loss: 0.8794 - val_accuracy: 0.5441 - val_loss: 2.0339 - learning_rate: 2.5000e-04
# Epoch 62/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8630 - loss: 0.8998 - val_accuracy: 0.5147 - val_loss: 2.0212 - learning_rate: 2.5000e-04
# Epoch 63/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8932 - loss: 0.8377 - val_accuracy: 0.4853 - val_loss: 2.0407 - learning_rate: 2.5000e-04
# Epoch 64/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8825 - loss: 0.8683 - val_accuracy: 0.5000 - val_loss: 2.0597 - learning_rate: 2.5000e-04
# Epoch 65/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8597 - loss: 0.9130 - val_accuracy: 0.5147 - val_loss: 2.0567 - learning_rate: 2.5000e-04
# Epoch 66/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8369 - loss: 0.9237 - val_accuracy: 0.5294 - val_loss: 2.0480 - learning_rate: 2.5000e-04
# Epoch 67/300
# 11/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8076 - loss: 0.9070
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8259 - loss: 0.8982 - val_accuracy: 0.5294 - val_loss: 2.0497 - learning_rate: 2.5000e-04
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 37.
#
# Test Accuracy: 0.5000
# Test Loss: 1.9323
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Healthy       0.12      0.17      0.14         6
#    Early CKD       0.56      0.38      0.45        24
# Moderate CKD       0.40      0.67      0.50        12
#   Severe CKD       0.75      0.67      0.71        18
#
#     accuracy                           0.50        60
#    macro avg       0.46      0.47      0.45        60
# weighted avg       0.54      0.50      0.51        60
# ============================================================
# Neural Network Test Accuracy: 0.5000
# ============================================================
